# %%
import pandas as pd

# %%
INPUT_DATA_DIR = "/chronos_data/avirinchipur/reasoning_for_psych/kjell_prolific/"
CSV_FILE = "response_format_cleaned_ds1_adi.csv"

# %%
data = pd.read_csv('{}{}'.format(INPUT_DATA_DIR, CSV_FILE))

# %%
data
# Out:
#         X     id           submitdate  lastpage startlanguage          seed  \
# 0       1  434.0  2020-08-07 11:46:22      15.0            en  6.593644e+08
# 1       2  184.0  2020-08-07 11:58:36      15.0            en  2.803892e+08
# 2       3  330.0  2020-08-07 11:51:54      15.0            en  6.770686e+07
# 3       4  630.0  2020-08-07 13:22:42      15.0            en  1.176643e+09
# 4       5  400.0  2020-08-07 12:04:52      15.0            en  1.012492e+09
# ..    ...    ...                  ...       ...           ...           ...
# 971  1004   32.0  2020-08-07 12:02:58      15.0            en  1.363161e+09
# 972  1005  344.0  2020-08-07 13:45:57      15.0            en  1.283747e+08
# 973  1006  297.0  2020-08-07 13:11:46      15.0            en  9.695994e+08
# 974  1007  241.0  2020-08-07 12:51:07      15.0            en  1.976520e+09
# 975  1008  350.0  2020-08-10 14:20:21      15.0            en  1.631209e+09
#
#                startdate            datestamp  sequence1  seqOne  ...  \
# 0    2020-08-07 11:38:22  2020-08-07 11:46:22        2.0     1.0  ...
# 1    2020-08-07 11:34:31  2020-08-07 11:58:36        2.0     1.0  ...
# 2    2020-08-07 11:36:32  2020-08-07 11:51:54        1.0     1.0  ...
# 3    2020-08-07 12:55:26  2020-08-07 13:22:42        3.0     1.0  ...
# 4    2020-08-07 11:37:19  2020-08-07 12:04:52        1.0     1.0  ...
# ..                   ...                  ...        ...     ...  ...
# 971  2020-08-07 11:45:11  2020-08-07 12:02:58        3.0     1.0  ...
# 972  2020-08-07 13:32:04  2020-08-07 13:45:57        3.0     1.0  ...
# 973  2020-08-07 12:52:04  2020-08-07 13:11:46        3.0     1.0  ...
# 974  2020-08-07 12:28:54  2020-08-07 12:51:07        2.0     1.0  ...
# 975  2020-08-10 14:11:02  2020-08-10 14:20:21        3.0     1.0  ...
#
#                                       wor_all_selected  \
# 0    NA NA happy NA NA NA NA NA NA NA NA NA NA care...
# 1    anxious NA NA NA NA NA NA NA NA NA NA tense NA...
# 2    anxious NA NA NA NA NA worried NA NA NA NA NA ...
# 3    anxious NA NA NA NA concerned NA NA NA NA NA t...
# 4    NA NA NA NA NA concerned NA NA NA NA NA tense ...
# ..                                                 ...
# 971  anxious NA NA NA NA NA NA NA NA NA NA NA scare...
# 972  NA NA NA nervous NA NA worried NA NA NA NA NA ...
# 973  NA NA NA NA NA NA NA NA stressed NA NA NA scar...
# 974  anxious NA NA NA NA NA worried NA stressed NA ...
# 975  NA NA NA nervous NA NA NA NA NA NA NA tense NA...
#
#                                      wor_all_selected1 minidep_scale  \
# 0      happy           carefree     satisfied      ...           0.0
# 1    anxious           tense    fearful  sad     fe...           3.0
# 2    anxious      worried      scared     sad   mon...           7.0
# 3    anxious     concerned      tense scared       ...           3.0
# 4         concerned      tense      sad      tired ...           4.0
# ..                                                 ...           ...
# 971  anxious            scared  uneasy fearful     ...           9.0
# 972     nervous   worried             stress  anxie...           7.0
# 973          stressed    scared   fearful      anxi...           7.0
# 974  anxious      worried  stressed      uneasy    ...           8.0
# 975     nervous        tense   uneasy     stress  a...           7.0
#
#     minidep_diagnose depression_episodes miniGAD_scale miniGAD_symptoms_scale  \
# 0                  0                   0             0                      0
# 1                  0                   0             8                      5
# 2                  0                   5             9                      5
# 3                  0                   5             8                      5
# 4                  0                   2             7                      4
# ..               ...                 ...           ...                    ...
# 971                1                   1             0                      0
# 972                1                   7            11                      6
# 973                1                   2            10                      5
# 974                1                   1            11                      6
# 975                0                   3             9                      6
#
#     miniGAD_diagnose minidiagnose_category minidiagnose_category_number
# 0                  0                  NoDi                            0
# 1                  0                  NoDi                            0
# 2                  0                  NoDi                            0
# 3                  0                  NoDi                            0
# 4                  1                   GAD                            2
# ..               ...                   ...                          ...
# 971                0                   Dep                            1
# 972                1                  BOTH                            3
# 973                1                  BOTH                            3
# 974                1                  BOTH                            3
# 975                1                   GAD                            2
#
# [976 rows x 408 columns]

# %%
for idx, col in enumerate(data.columns):
    if idx%8 == 0: print ()
    print ("{},".format(col), end=" ")
# Out:
# X, id, submitdate, lastpage, startlanguage, seed, startdate, datestamp,
# sequence1, seqOne, Dep5words.Word1., Dep5words.Word2., Dep5words.Word3., Dep5words.Word4., Dep5words.Word5., Wor5words.SQ01.,
# Wor5words.SQ02., Wor5words.SQ03., Wor5words.SQ04., Wor5words.SQ05., sequence2, seq2, Dep5phraseorwords.SQ01., Dep5phraseorwords.SQ02.,
# Dep5phraseorwords.SQ03., Dep5phraseorwords.SQ04., Dep5phraseorwords.SQ05., Wor5phraseorwords.SQ01., Wor5phraseorwords.SQ02., Wor5phraseorwords.SQ03., Wor5phraseorwords.SQ04., Wor5phraseorwords.SQ05.,
# sequence3, seq3, Deptext, Wortext, DepselectCol.happy., DepselectCol.sad., DepselectCol.content., DepselectCol.joyful.,
# DepselectCol.satisfied., DepselectCol.tired., DepselectCol.peaceful., DepselectCol.cheerful., DepselectCol.excited., DepselectCol.calm., DepselectCol.hopeful., DepselectCol.down.,
# DepselectCol.anxious., DepselectCol.unhappy., DepselectCol.worried., DepselectCol.optimistic., DepselectCol.blue., DepselectCol.lonely., DepselectCol.relaxed., DepselectCol.pleased.,
# DepselectCol.stressed., DepselectCol.depressed., DepselectCol.active., DepselectCol.angry., DepselectCol.fun., DepselectCol.loving., DepselectCol.upbeat., DepselectCol.blessed.,
# DepselectCol.joy., DepselectCol.love., DepselectCol.loved., WorselectCol.anxious., WorselectCol.calm., WorselectCol.happy., WorselectCol.nervous., WorselectCol.relaxed.,
# WorselectCol.concerned., WorselectCol.worried., WorselectCol.content., WorselectCol.stressed., WorselectCol.peaceful., WorselectCol.upset., WorselectCol.tense., WorselectCol.scared.,
# WorselectCol.carefree., WorselectCol.uneasy., WorselectCol.fearful., WorselectCol.hopeful., WorselectCol.sad., WorselectCol.satisfied., WorselectCol.stress., WorselectCol.money.,
# WorselectCol.anxiety., WorselectCol.fear., WorselectCol.tired., WorselectCol.unworried., WorselectCol.troubled., WorselectCol.confident., WorselectCol.thoughtful., WorselectCol.bothered.,
# WorselectCol.peace., WorselectCol.untroubled., PHQ.SQ01., PHQ.SQ02., PHQ.SQ03., PHQ.SQ04., PHQ.SQ05., PHQ.SQ06.,
# PHQ.SQ07., PHQ.SQ08., PHQ.SQ09., PHQ.SQ10., PHQextra, CESD.SQ01., CESD.SQ02., CESD.SQ03.,
# CESD.SQ04., CESD.SQ05., CESD.SQ06., CESD.SQ07., CESD.SQ08., CESD.SQ09., CESD.SQ10., CESD.SQ11.,
# CESD.SQ12., CESD.SQ13., CESD.SQ14., CESD.SQ15., CESD.SQ16., CESD.SQ17., CESD.SQ18., CESD.SQ19.,
# CESD.SQ20., GADsurvey.SQ01., GADsurvey.SQ02., GADsurvey.SQ03., GADsurvey.SQ04., GADsurvey.SQ05., GADsurvey.SQ06., GADsurvey.SQ07.,
# GADsurvey.SQ08., GADextra, PSWQsurvey.SQ01., PSWQsurvey.SQ02., PSWQsurvey.SQ03., PSWQsurvey.SQ04., PSWQsurvey.SQ05., PSWQsurvey.SQ06.,
# PSWQsurvey.SQ07., PSWQsurvey.SQ08., PSWQsurvey.SQ09., PSWQsurvey.SQ10., PSWQsurvey.SQ11., PSWQsurvey.SQ12., PSWQsurvey.SQ13., PSWQsurvey.SQ14.,
# PSWQsurvey.SQ15., PSWQsurvey.SQ16., A1, A2, A3a, A3b1, A3c1, A3d1,
# A3e1, A3f1, A3g1, A4a, A5, A6, N1a, N1a2,
# N1b, N2, N3a, N3b, N3c, N3d, N3e, N3f,
# N4, Diagnosis.SQ01., Diagnosis.SQ02., Diagnosis.SQ03., Diagnosis.SQ04., SickDaysMonth, MentalSickDays, SickDaysYear,
# MentalSickDaysYear, HealthCareVisits, HealthCareMental, Treatment.SQ01., Treatment.SQ02., Treatment.SQ03., Treatment.SQ04., Treatment.other.,
# Gender, Age, interviewtime, ProlificIDTime, sequence1Time, seqOneTime, Dep5wordsTime, Wor5wordsTime,
# sequence2Time, seq2Time, Dep5phraseorwordsTime, Wor5phraseorwordsTime, sequence3Time, seq3Time, DeptextTime, WortextTime,
# DepselectColTime, WorselectColTime, PHQTime, PHQextraTime, CESDTime, GADsurveyTime, GADextraTime, PSWQsurveyTime,
# A1Time, A2Time, A3aTime, A3b1Time, A3c1Time, A3d1Time, A3e1Time, A3f1Time,
# A3g1Time, A4aTime, A5Time, A6Time, N1aTime, N1a2Time, N1bTime, N2Time,
# N3aTime, N3bTime, N3cTime, N3dTime, N3eTime, N3fTime, N4Time, DiagnosisTime,
# SickDaysMonthTime, MentalSickDaysTime, SickDaysYearTime, MentalSickDaysYearTime, HealthCareVisitsTime, HealthCareMentalTime, TreatmentTime, GenderTime,
# AgeTime, session_id, status, started_datetime, completed_date_time, time_taken, age, num_approvals,
# num_rejections, prolific_score, reviewed_at_datetime, entered_code, Country.of.Birth, Current.Country.of.Residence, Employment.Status, First.Language,
# Nationality, Sex, Student.Status, PHQ1, PHQ2, PHQ3, PHQ4, PHQ5,
# PHQ6, PHQ7, PHQ8, PHQ9, PHQ_control2, CESD1, CESD2, CESD3,
# CESD4, CESD5, CESD6, CESD7, CESD8, CESD9, CESD10, CESD11,
# CESD12, CESD13, CESD14, CESD15, CESD16, CESD17, CESD18, CESD19,
# CESD20, GAD1, GAD2, GAD3, GAD4, GAD5, GAD6, GAD7,
# GADcontrol1, PSWQ1, PSWQ2, PSWQ3, PSWQ4, PSWQ5, PSWQ6, PSWQ7,
# PSWQ8, PSWQ9, PSWQ10, PSWQ11, PSWQ12, PSWQ13, PSWQ14, PSWQ15,
# PSWQ16, PHQtot, GADtot, PSWQtot, CESD4rev, CESD8rev, CESD12rev, CESD16rev,
# CESDtot, dep_all_words, wor_all_words, dep_all_phraces, wor_all_phraces, dep_text, wor_text, DepselectCol_happy,
# DepselectCol_sad, DepselectCol_content, DepselectCol_joyful, DepselectCol_satisfied, DepselectCol_tired, DepselectCol_peaceful, DepselectCol_cheerful, DepselectCol_excited,
# DepselectCol_calm, DepselectCol_hopeful, DepselectCol_down, DepselectCol_anxious, DepselectCol_unhappy, DepselectCol_worried, DepselectCol_optimistic, DepselectCol_blue,
# DepselectCol_lonely, DepselectCol_relaxed, DepselectCol_pleased, DepselectCol_stressed, DepselectCol_depressed, DepselectCol_active, DepselectCol_angry, DepselectCol_fun,
# DepselectCol_loving, DepselectCol_upbeat, DepselectCol_blessed, DepselectCol_joy, DepselectCol_love, dep_all_selected, dep_all_selected1, WorselectCol_anxious,
# WorselectCol_calm, WorselectCol_happy, WorselectCol_nervous, WorselectCol_relaxed, WorselectCol_concerned, WorselectCol_worried, WorselectCol_content, WorselectCol_stressed,
# WorselectCol_peaceful, WorselectCol_upset, WorselectCol_tense, WorselectCol_scared, WorselectCol_carefree, WorselectCol_uneasy, WorselectCol_fearful, WorselectCol_hopeful,
# WorselectCol_sad, WorselectCol_satisfied, WorselectCol_stress, WorselectCol_money, WorselectCol_anxiety, WorselectCol_fear, WorselectCol_tired, WorselectCol_unworried,
# WorselectCol_troubled, WorselectCol_confident, WorselectCol_thoughtful, WorselectCol_bothered, WorselectCol_peace, WorselectCol_untroubled, wor_all_selected, wor_all_selected1,
# minidep_scale, minidep_diagnose, depression_episodes, miniGAD_scale, miniGAD_symptoms_scale, miniGAD_diagnose, minidiagnose_category, minidiagnose_category_number,
